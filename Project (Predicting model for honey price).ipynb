# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn

# %%
data = pd.read_csv(r"C:\Users\user\Downloads\honey_purity_dataset.csv")

# %%
data
# Out:
#           CS  Density     WC    pH    EC      F      G Pollen_analysis  \
# 0       2.81     1.75  23.04  6.29  0.76  39.02  33.63       Blueberry
# 1       9.47     1.82  17.50  7.20  0.71  38.15  34.41         Alfalfa
# 2       4.61     1.84  23.72  7.31  0.80  27.47  34.36        Chestnut
# 3       1.77     1.40  16.61  4.01  0.78  31.52  28.15       Blueberry
# 4       6.11     1.25  19.63  4.82  0.90  29.65  42.52         Alfalfa
# ...      ...      ...    ...   ...   ...    ...    ...             ...
# 247898  1.98     1.29  17.90  4.82  0.89  36.10  34.69        Rosemary
# 247899  6.18     1.67  19.54  4.91  0.85  31.15  20.82          Acacia
# 247900  7.78     1.49  15.78  5.69  0.73  44.60  44.07        Chestnut
# 247901  5.78     1.74  14.96  6.81  0.83  47.19  37.79         Avocado
# 247902  8.96     1.86  18.62  6.89  0.86  25.94  42.88        Lavender
#
#         Viscosity  Purity   Price
# 0         4844.50    0.68  645.24
# 1         6689.02    0.89  385.85
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 247903 entries, 0 to 247902
# Data columns (total 11 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   CS               247903 non-null  float64
#  1   Density          247903 non-null  float64
#  2   WC               247903 non-null  float64
#  3   pH               247903 non-null  float64
#  4   EC               247903 non-null  float64
#  5   F                247903 non-null  float64
#  6   G                247903 non-null  float64
#  7   Pollen_analysis  247903 non-null  object
#  8   Viscosity        247903 non-null  float64
#  9   Purity           247903 non-null  float64
#  10  Price            247903 non-null  float64
# dtypes: float64(10), object(1)
# memory usage: 20.8+ MB

# %%
data.columns
# Out:
# Index(['CS', 'Density', 'WC', 'pH', 'EC', 'F', 'G', 'Pollen_analysis',
#        'Viscosity', 'Purity', 'Price'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# CS                 0
# Density            0
# WC                 0
# pH                 0
# EC                 0
# F                  0
# G                  0
# Pollen_analysis    0
# Viscosity          0
# Purity             0
# Price              0
# dtype: int64

# %%
data.duplicated().any()
# Out:
# False

# %%
data.skew()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_19536\1188251951.py:1: FutureWarning: The default value of numeric_only in DataFrame.skew is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.skew()
# CS           0.000062
# Density     -0.000805
# WC          -0.002823
# pH           0.002843
# EC           0.000804
# F            0.000789
# G           -0.000315
# Viscosity   -0.003851
# Purity      -0.071791
# Price       -0.244702
# dtype: float64

# %%
data.kurtosis()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_19536\2361870383.py:1: FutureWarning: The default value of numeric_only in DataFrame.kurt is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.kurtosis()
# CS          -1.196323
# Density     -1.200521
# WC          -1.199574
# pH          -1.201069
# EC          -1.187623
# F           -1.199137
# G           -1.202248
# Viscosity   -1.201837
# Purity      -1.521316
# Price       -0.876176
# dtype: float64

# %%
data.describe()
# Out:
#                   CS        Density             WC             pH  \
# count  247903.000000  247903.000000  247903.000000  247903.000000
# mean        5.500259       1.535523      18.502625       4.996047
# std         2.593947       0.187824       3.748635       1.444060
# min         1.000000       1.210000      12.000000       2.500000
# 25%         3.260000       1.370000      15.260000       3.750000
# 50%         5.500000       1.540000      18.510000       4.990000
# 75%         7.740000       1.700000      21.750000       6.250000
# max        10.000000       1.860000      25.000000       7.500000
#
#                   EC              F              G      Viscosity  \
# count  247903.000000  247903.000000  247903.000000  247903.000000
# mean        0.799974      34.970573      32.501006    5752.893888
# std         0.057911       8.655898       7.226290    2455.739903
# min         0.700000      20.000000      20.000000    1500.050000
# ...

# %%
data.corr()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_19536\2627137660.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#                  CS   Density        WC        pH        EC         F  \
# CS         1.000000 -0.001099  0.001148  0.000267 -0.000215 -0.003287
# Density   -0.001099  1.000000 -0.000037  0.002389 -0.004113  0.000515
# WC         0.001148 -0.000037  1.000000  0.001068  0.000690  0.000912
# pH         0.000267  0.002389  0.001068  1.000000 -0.001400  0.000511
# EC        -0.000215 -0.004113  0.000690 -0.001400  1.000000 -0.001773
# F         -0.003287  0.000515  0.000912  0.000511 -0.001773  1.000000
# G          0.001217  0.002244  0.003517 -0.000725 -0.002520 -0.000683
# Viscosity -0.000099 -0.003295 -0.001088 -0.002347 -0.001755 -0.000023
# ...

# %%
plt.figure(figsize = (12,8))
sn.heatmap(data.corr() , annot = True , cmap = "tab20")
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_19536\2371788782.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sn.heatmap(data.corr() , annot = True , cmap = "tab20")
# <Axes: >

# %%
from scipy import stats

# %%
stats.probplot(data["Price"] , plot = plt)
# Out:
# ((array([-4.54125343, -4.35064384, -4.2472453 , ...,  4.2472453 ,
#           4.35064384,  4.54125343]),
#   array([128.72, 128.72, 128.72, ..., 976.69, 976.69, 976.69])),
#  (229.0586573806055, 594.8076444415759, 0.9804252880779151))

# %%
data.columns
# Out:
# Index(['CS', 'Density', 'WC', 'pH', 'EC', 'F', 'G', 'Pollen_analysis',
#        'Viscosity', 'Purity', 'Price'],
#       dtype='object')

# %%
data.head()
# Out:
#      CS  Density     WC    pH    EC      F      G Pollen_analysis  Viscosity  \
# 0  2.81     1.75  23.04  6.29  0.76  39.02  33.63       Blueberry    4844.50
# 1  9.47     1.82  17.50  7.20  0.71  38.15  34.41         Alfalfa    6689.02
# 2  4.61     1.84  23.72  7.31  0.80  27.47  34.36        Chestnut    6883.60
# 3  1.77     1.40  16.61  4.01  0.78  31.52  28.15       Blueberry    7167.56
# 4  6.11     1.25  19.63  4.82  0.90  29.65  42.52         Alfalfa    5125.44
#
#    Purity   Price
# 0    0.68  645.24
# 1    0.89  385.85
# 2    0.66  639.64
# 3    1.00  946.46
# 4    1.00  432.62

# %%
for i in ["CS","Density","WC","pH","EC","F","G","Viscosity","Purity"]:
    stats.probplot(data[i] , plot = plt)
    plt.title(i)
    plt.grid()
    plt.tight_layout()
    plt.show()

# %%
for i in ["CS","Density","WC","pH","EC","F","G","Viscosity","Purity"]:
    sn.boxplot(data[i] , color = "red")
    plt.title(i)
    plt.show()

# %%
for i in ["CS","Density","WC","pH","EC","F","G","Viscosity","Purity"]:
    plt.figure(figsize = (12,4))
    sn.distplot(data[i] , color = "green")
    plt.title(i)
    plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_19536\2881757407.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(data[i] , color = "green")
# C:\Users\user\AppData\Local\Temp\ipykernel_19536\2881757407.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
data["Pollen_analysis"].value_counts()
# Out:
# Eucalyptus        13194
# Avocado           13191
# Heather           13187
# Thyme             13156
# Sunflower         13148
# Sage              13117
# Blueberry         13106
# Lavender          13086
# Alfalfa           13049
# Buckwheat         13036
# Chestnut          13020
# Wildflower        13016
# Manuka            13003
# Borage            13000
# Orange Blossom    12992
# Acacia            12976
# Rosemary          12930
# Clover            12910
# Tupelo            12786
# Name: Pollen_analysis, dtype: int64

# %%
data.shape
# Out:
# (247903, 11)

# %%
data_p = data["Pollen_analysis"]

# %%
data_p
# Out:
# 0         Blueberry
# 1           Alfalfa
# 2          Chestnut
# 3         Blueberry
# 4           Alfalfa
#             ...
# 247898     Rosemary
# 247899       Acacia
# 247900     Chestnut
# 247901      Avocado
# 247902     Lavender
# Name: Pollen_analysis, Length: 247903, dtype: object

# %%
data_p = pd.DataFrame(data_p)

# %%
data_p
# Out:
#        Pollen_analysis
# 0            Blueberry
# 1              Alfalfa
# 2             Chestnut
# 3            Blueberry
# 4              Alfalfa
# ...                ...
# 247898        Rosemary
# 247899          Acacia
# 247900        Chestnut
# 247901         Avocado
# 247902        Lavender
#
# [247903 rows x 1 columns]

# %%
from sklearn.preprocessing import LabelEncoder ,StandardScaler

# %%
le = LabelEncoder()
data_p = data_p.apply(le.fit_transform)

# %%
data_p
# Out:
#         Pollen_analysis
# 0                     3
# 1                     1
# 2                     6
# 3                     3
# 4                     1
# ...                 ...
# 247898               13
# 247899                0
# 247900                6
# 247901                2
# 247902               10
#
# [247903 rows x 1 columns]

# %%
data = data.drop(["Pollen_analysis"] ,axis = 1)

# %%
data
# Out:
#           CS  Density     WC    pH    EC      F      G  Viscosity  Purity  \
# 0       2.81     1.75  23.04  6.29  0.76  39.02  33.63    4844.50    0.68
# 1       9.47     1.82  17.50  7.20  0.71  38.15  34.41    6689.02    0.89
# 2       4.61     1.84  23.72  7.31  0.80  27.47  34.36    6883.60    0.66
# 3       1.77     1.40  16.61  4.01  0.78  31.52  28.15    7167.56    1.00
# 4       6.11     1.25  19.63  4.82  0.90  29.65  42.52    5125.44    1.00
# ...      ...      ...    ...   ...   ...    ...    ...        ...     ...
# 247898  1.98     1.29  17.90  4.82  0.89  36.10  34.69    8261.63    1.00
# 247899  6.18     1.67  19.54  4.91  0.85  31.15  20.82    6939.39    1.00
# 247900  7.78     1.49  15.78  5.69  0.73  44.60  44.07    4139.79    0.64
# 247901  5.78     1.74  14.96  6.81  0.83  47.19  37.79    4417.74    0.97
# 247902  8.96     1.86  18.62  6.89  0.86  25.94  42.88    8119.62    0.64
#
#          Price
# 0       645.24
# 1       385.85
# 2       639.64
# ...

# %%
data = pd.concat([data , data_p] , axis = 1)

# %%
data
# Out:
#           CS  Density     WC    pH    EC      F      G  Viscosity  Purity  \
# 0       2.81     1.75  23.04  6.29  0.76  39.02  33.63    4844.50    0.68
# 1       9.47     1.82  17.50  7.20  0.71  38.15  34.41    6689.02    0.89
# 2       4.61     1.84  23.72  7.31  0.80  27.47  34.36    6883.60    0.66
# 3       1.77     1.40  16.61  4.01  0.78  31.52  28.15    7167.56    1.00
# 4       6.11     1.25  19.63  4.82  0.90  29.65  42.52    5125.44    1.00
# ...      ...      ...    ...   ...   ...    ...    ...        ...     ...
# 247898  1.98     1.29  17.90  4.82  0.89  36.10  34.69    8261.63    1.00
# 247899  6.18     1.67  19.54  4.91  0.85  31.15  20.82    6939.39    1.00
# 247900  7.78     1.49  15.78  5.69  0.73  44.60  44.07    4139.79    0.64
# 247901  5.78     1.74  14.96  6.81  0.83  47.19  37.79    4417.74    0.97
# 247902  8.96     1.86  18.62  6.89  0.86  25.94  42.88    8119.62    0.64
#
#          Price  Pollen_analysis
# 0       645.24                3
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
import statsmodels.formula.api as smf

# %%
from sklearn.linear_model import LinearRegression
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import adam

# %%
x = data.drop(["Price"] , axis = 1)
y = data["Price"]

# %%
x_train , x_test , y_train , y_test = train_test_split(x , y , test_size = 0.20 , random_state = 42)

# %%
x_train.shape , x_test.shape
# Out:
# ((198322, 10), (49581, 10))

# %%
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
x_train
# Out:
# array([[ 6.54696543e-01, -1.62772010e+00,  1.35969859e+00, ...,
#         -4.35631367e-01, -1.18132383e+00,  5.49215208e-01],
#        [ 2.41878240e-01,  8.23241222e-01,  1.06345488e+00, ...,
#         -2.45043671e-01,  1.18468016e+00, -1.46051030e+00],
#        [ 2.38020125e-01, -8.28493583e-01,  2.92153696e-01, ...,
#          1.63216512e+00,  1.25637726e+00,  1.10825269e-03],
#        ...,
#        [-1.00043479e+00,  4.50268847e-01,  6.09748301e-01, ...,
#          8.77656249e-01, -1.32471801e+00,  1.09732216e+00],
#        [ 1.14081903e+00,  1.30277713e+00, -9.00827721e-01, ...,
#          1.41487178e+00, -1.18132383e+00, -1.09510566e+00],
#        [ 4.27067759e-01, -1.20146596e+00, -6.55292396e-01, ...,
#          9.53730092e-01,  8.97891802e-01,  1.09732216e+00]])

# %%
model = LinearRegression()

# %%
model.fit(x_train , y_train)
# Out:
# LinearRegression()

# %%
y_model_pred = model.predict(x_test)

# %%
y_model_pred
# Out:
# array([466.77766176, 736.75654312, 605.40011115, ..., 681.10362688,
#        720.1606074 , 621.44096259])

# %%
mse = np.mean((y_test-y_model_pred)**2)

# %%
rmse = np.sqrt(mse)

# %%
print("rmse_linear_model:",rmse)
# Out:
# rmse_linear_model: 209.71100581616957

# %%
pd.DataFrame({"y_test":y_test , "y_model_pred":y_model_pred})
# Out:
#         y_test  y_model_pred
# 29002   384.48    466.777662
# 13563   319.27    736.756543
# 12445   584.69    605.400111
# 233689  469.07    443.249692
# 52643   353.38    572.137883
# ...        ...           ...
# 212780  810.40    645.536085
# 234265  744.91    710.814130
# 167828  915.33    681.103627
# 24205   694.53    720.160607
# 13778   593.33    621.440963
#
# [49581 rows x 2 columns]

# %%
model_tree = DecisionTreeRegressor(criterion = "friedman_mse" , max_depth = 5)

# %%
model_tree.fit(x_train , y_train)
# Out:
# DecisionTreeRegressor(criterion='friedman_mse', max_depth=5)

# %%
y_tree_pred = model_tree.predict(x_test)

# %%
y_tree_pred
# Out:
# array([414.60228391, 319.05314607, 579.73972963, ..., 790.83935294,
#        579.73972963, 790.83935294])

# %%
mse_tree = np.mean((y_test-y_tree_pred)**2)

# %%
rmse_tree = np.sqrt(mse_tree)
print("rmse_tree_model:",rmse_tree)
# Out:
# rmse_tree_model: 155.72827468787207

# %%
pd.DataFrame({"y_test":y_test , "y_tree_pred":y_tree_pred})
# Out:
#         y_test  y_tree_pred
# 29002   384.48   414.602284
# 13563   319.27   319.053146
# 12445   584.69   579.739730
# 233689  469.07   568.539268
# 52643   353.38   395.920182
# ...        ...          ...
# 212780  810.40   811.912237
# 234265  744.91   790.839353
# 167828  915.33   790.839353
# 24205   694.53   579.739730
# 13778   593.33   790.839353
#
# [49581 rows x 2 columns]

# %%
from sklearn.tree import plot_tree

# %%
plt.figure(figsize = (24,8))
plot_tree(model_tree , filled = True)
# Out:
# [Text(0.49375, 0.9166666666666666, 'x[8] <= -0.321\nfriedman_mse = 54622.184\nsamples = 198322\nvalue = 595.136'),
#  Text(0.25416666666666665, 0.75, 'x[9] <= 1.554\nfriedman_mse = 27866.276\nsamples = 69610\nvalue = 474.515'),
#  Text(0.13333333333333333, 0.5833333333333334, 'x[9] <= 0.823\nfriedman_mse = 25437.976\nsamples = 66063\nvalue = 488.649'),
#  Text(0.06666666666666667, 0.4166666666666667, 'x[9] <= -1.369\nfriedman_mse = 27729.961\nsamples = 51456\nvalue = 456.388'),
#  Text(0.03333333333333333, 0.25, 'x[9] <= -1.552\nfriedman_mse = 1476.638\nsamples = 7371\nvalue = 320.549'),
#  Text(0.016666666666666666, 0.08333333333333333, 'friedman_mse = 197.301\nsamples = 3676\nvalue = 356.747'),
#  Text(0.05, 0.08333333333333333, 'friedman_mse = 148.94\nsamples = 3695\nvalue = 284.537'),
#  Text(0.1, 0.25, 'x[9] <= -0.456\nfriedman_mse = 28518.485\nsamples = 44085\nvalue = 479.1'),
# ...

# %%
model_forest = RandomForestRegressor(n_estimators = 100  , max_features = 5)

# %%
model_forest.fit(x_train , y_train)
# Out:
# RandomForestRegressor(max_features=5)

# %%
y_pred_forest = model_forest.predict(x_test)

# %%
y_pred_forest
# Out:
# array([384.2383, 319.27  , 587.0656, ..., 900.8143, 697.3515, 603.9003])

# %%
mse_forest = np.mean((y_test-y_pred_forest)**2)

# %%
rmse_forest = np.sqrt(mse_forest)
print("rmse_forest_model:",rmse_forest)
# Out:
# rmse_forest_model: 10.189677874162557

# %%
data.shape
# Out:
# (247903, 11)

# %%
model_neural = Sequential()
model_neural.add(Dense(11 , input_dim = 10 , activation = "relu")) ## input layer
model_neural.add(Dense(12 , activation = "relu" )) ##1st hidden layer
model_neural.add(Dense(24  , activation = "relu")) ## 2nd hidden layer
model_neural.add(Dense(36 , activation = "relu")) ## 3rd hidden layer
model_neural.add(Dense(18 ,activation = "relu")) ## 4th hidden layer
model_neural.add(Dense(9 , activation = "relu")) ## 5 th hidden layer
model_neural.add(Dense(1 , activation = "linear")) ## output layer

# %%
model_neural.compile(loss = "mean_squared_error" , optimizer = "adam")

# %%
history = model_neural.fit(x_train , y_train , batch_size = 10 , epochs = 25 , validation_split = 0.20)
# Out:
# Epoch 1/25
# 15866/15866 [==============================] - 42s 3ms/step - loss: 48716.7266 - val_loss: 44381.8555
# Epoch 2/25
# 15866/15866 [==============================] - 39s 2ms/step - loss: 44949.0625 - val_loss: 44226.2969
# Epoch 3/25
# 15866/15866 [==============================] - 39s 2ms/step - loss: 43549.9023 - val_loss: 39470.4102
# Epoch 4/25
# 15866/15866 [==============================] - 39s 2ms/step - loss: 33404.8867 - val_loss: 26060.0625
# Epoch 5/25
# 15866/15866 [==============================] - 39s 2ms/step - loss: 12205.5527 - val_loss: 4172.5166
# Epoch 6/25
# 15866/15866 [==============================] - 38s 2ms/step - loss: 748.2593 - val_loss: 95.3083
# Epoch 7/25
# 15866/15866 [==============================] - 38s 2ms/step - loss: 506.5256 - val_loss: 30.6299
# Epoch 8/25
# 15866/15866 [==============================] - 37s 2ms/step - loss: 224.1982 - val_loss: 24.0019
# Epoch 9/25
# ...

# %%
from matplotlib import pyplot

# %%
pyplot.plot(history.history["loss"] , label = "train")
pyplot.plot(history.history["val_loss"],label = "test")
plt.title("mean_squared_error")
# Out:
# Text(0.5, 1.0, 'mean_squared_error')
